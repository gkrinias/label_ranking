# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']

# %%
def plot(dimensionality='SFN', noise_type='additive', noise_measurement='alpha'):
  noise_measurements = []

  for i in range(50):
    with open(f'datasets/{dimensionality}/{noise_type}/{noise_measurement}_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    noise_measurements.append(data[noise_measurement])

  noise_measurements = sorted(noise_measurements)

  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_dt.pickle', 'rb') as handle:
    pairwise_dt = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_dt.pickle', 'rb') as handle:
    labelwise_dt = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_rf.pickle', 'rb') as handle:
    pairwise_rf = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_rf.pickle', 'rb') as handle:
    labelwise_rf = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_hh.pickle', 'rb') as handle:
    pairwise_hh = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_lr.pickle', 'rb') as handle:
    labelwise_lr = pickle.load(handle)

  plt.rcParams['text.usetex'] = True
  plt.figure() # (figsize=(16, 6))
  plt.title(dimensionality + ' ' + noise_type)
  plt.plot(noise_measurements, labelwise_lr)
  plt.plot(noise_measurements, labelwise_dt)
  plt.plot(noise_measurements, labelwise_rf)
  plt.plot(noise_measurements, pairwise_hh)
  plt.plot(noise_measurements, pairwise_dt)
  plt.plot(noise_measurements, pairwise_rf)
  plt.legend([
    'LWLR',
    'LWDT',
    'LWRF',
    'PWHH',
    'PWDT',
    'PWRF',
    ], 
    fontsize=12
  )
  plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.xlabel(f"$\{noise_measurement}$")
  plt.ylabel('Mean Kendall rank correlation coefficient')
  plt.grid(visible=True, which='major', color='0.8', linestyle='-')
  plt.grid(visible=True, which='minor', color='0.9', linestyle='--')
  plt.minorticks_on()
  plt.show()

# %%
def plot2(dimensionality='SFN', noise_type='additive'):

  noise_measurements = []

  noise_measurement = 'alpha'

  for i in range(50):
    with open(f'datasets/{dimensionality}/{noise_type}/{noise_measurement}_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    noise_measurements.append(data[noise_measurement])

  noise_measurements = sorted(noise_measurements)

  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_dt.pickle', 'rb') as handle:
    pairwise_dt = pickle.load(handle)
    print(pairwise_dt)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_dt.pickle', 'rb') as handle:
    labelwise_dt = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_rf.pickle', 'rb') as handle:
    pairwise_rf = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_rf.pickle', 'rb') as handle:
    labelwise_rf = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_hh.pickle', 'rb') as handle:
    pairwise_hh = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_lr.pickle', 'rb') as handle:
    labelwise_lr = pickle.load(handle)

  plt.rcParams['text.usetex'] = True
  
  fig = plt.figure(figsize=(8, 4))
  # fig.suptitle('SFN datasets with Gaussian additive noise', fontsize=12)
  # plt.title(dimensionality + ' ' + noise_type)

  fig.add_subplot(1, 2, 1) # .title.set_text(dimensionality + ' ' + noise_type)
  # plt.title(dimensionality + ' ' + noise_type)
  plt.plot(noise_measurements, labelwise_lr)
  plt.plot(noise_measurements, labelwise_dt)
  plt.plot(noise_measurements, labelwise_rf)
  plt.plot(noise_measurements, pairwise_hh)
  plt.plot(noise_measurements, pairwise_dt)
  plt.plot(noise_measurements, pairwise_rf)
  plt.legend([
    'LWLR',
    'LWDT',
    'LWRF',
    'PWHH',
    'PWDT',
    'PWRF',
    ],
    #title=dimensionality,
    framealpha=0.6,
    loc=3,
    fontsize=10
  )
  plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.yticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.xlabel(f"$\{noise_measurement}$")
  plt.ylabel("Mean KT coefficient")
  plt.grid(visible=True, which='major', color='0.8', linestyle='-')
  plt.grid(visible=True, which='minor', color='0.9', linestyle='--')
  plt.minorticks_on()

  noise_measurements = []

  noise_measurement = 'beta'

  for i in range(50):
    with open(f'datasets/{dimensionality}/{noise_type}/{noise_measurement}_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    noise_measurements.append(data[noise_measurement])

  noise_measurements = sorted(noise_measurements)

  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_dt.pickle', 'rb') as handle:
    pairwise_dt = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_dt.pickle', 'rb') as handle:
    labelwise_dt = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_rf.pickle', 'rb') as handle:
    pairwise_rf = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_rf.pickle', 'rb') as handle:
    labelwise_rf = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_pairwise_hh.pickle', 'rb') as handle:
    pairwise_hh = pickle.load(handle)
  with open(f'results/{dimensionality}/{noise_type}/{noise_measurement}_labelwise_lr.pickle', 'rb') as handle:
    labelwise_lr = pickle.load(handle)

  plt.rcParams['text.usetex'] = True

  fig.add_subplot(1, 2, 2) #.title.set_text(dimensionality + ' ' + noise_type)
  # plt.title(dimensionality + ' ' + noise_type)
  plt.plot(noise_measurements, labelwise_lr)
  plt.plot(noise_measurements, labelwise_dt)
  plt.plot(noise_measurements, labelwise_rf)
  plt.plot(noise_measurements, pairwise_hh)
  plt.plot(noise_measurements, pairwise_dt)
  plt.plot(noise_measurements, pairwise_rf)
  plt.legend([
    'LWLR',
    'LWDT',
    'LWRF',
    'PWHH',
    'PWDT',
    'PWRF',
    ],
    #title=dimensionality,
    framealpha=0.6,
    loc=4,
    fontsize=10
  )
  plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.yticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.xlabel(f"$\{noise_measurement}$")
  # plt.ylabel('Mean Kendall rank correlation coefficient')
  plt.grid(visible=True, which='major', color='0.8', linestyle='-')
  plt.grid(visible=True, which='minor', color='0.9', linestyle='--')
  plt.minorticks_on()
  
  plt.savefig(f'plots/{dimensionality}_{noise_type}.pdf')
  plt.show()

# %%
plot2(dimensionality='SFN', noise_type='additive')
plot2(dimensionality='MFN', noise_type='additive')
plot2(dimensionality='SFN', noise_type='mallows')
plot2(dimensionality='MFN', noise_type='mallows')

# %%
def plot3(algo):

  alphas_add = []

  for i in range(50):
    with open(f'datasets/SFN/additive/alpha_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    alphas_add.append(data['alpha'])

  alphas_add = sorted(alphas_add)

  with open(f'results/SFN/additive/alpha_{algo}.pickle', 'rb') as handle:
    kt_add_alpha = pickle.load(handle)

  
  betas_add = []

  for i in range(50):
    with open(f'datasets/SFN/additive/beta_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    betas_add.append(data['beta'])

  betas_add = sorted(betas_add)

  with open(f'results/SFN/additive/beta_{algo}.pickle', 'rb') as handle:
    kt_add_beta = pickle.load(handle)




  alphas_add_lfn = []

  for i in range(50):
    with open(f'datasets/MFN/additive/alpha_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    alphas_add_lfn.append(data['alpha'])

  alphas_add_lfn = sorted(alphas_add_lfn)

  with open(f'results/MFN/additive/alpha_{algo}.pickle', 'rb') as handle:
    kt_add_alpha_lfn = pickle.load(handle)


  

  betas_add_lfn = []

  for i in range(50):
    with open(f'datasets/MFN/additive/beta_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    betas_add_lfn.append(data['beta'])

  betas_add_lfn = sorted(betas_add_lfn)

  with open(f'results/MFN/additive/beta_{algo}.pickle', 'rb') as handle:
    kt_add_beta_lfn = pickle.load(handle)



  alphas_mal = []

  for i in range(50):
    with open(f'datasets/SFN/mallows/alpha_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    alphas_mal.append(data['alpha'])

  alphas_mal = sorted(alphas_mal)

  with open(f'results/SFN/mallows/alpha_{algo}.pickle', 'rb') as handle:
    kt_mal_alpha = pickle.load(handle)

  

  betas_mal = []

  for i in range(50):
    with open(f'datasets/SFN/mallows/beta_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    betas_mal.append(data['beta'])

  betas_mal = sorted(betas_mal)

  with open(f'results/SFN/mallows/beta_{algo}.pickle', 'rb') as handle:
    kt_mal_beta = pickle.load(handle)




  alphas_mal_lfn = []

  for i in range(50):
    with open(f'datasets/MFN/mallows/alpha_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    alphas_mal_lfn.append(data['alpha'])

  alphas_mal_lfn = sorted(alphas_mal_lfn)

  with open(f'results/MFN/mallows/alpha_{algo}.pickle', 'rb') as handle:
    kt_mal_alpha_lfn = pickle.load(handle)



  betas_mal_lfn = []

  for i in range(50):
    with open(f'datasets/MFN/mallows/beta_{i}.pickle', 'rb') as handle:
      data = pickle.load(handle)
    betas_mal_lfn.append(data['beta'])

  betas_mal_lfn = sorted(betas_mal_lfn)

  with open(f'results/MFN/mallows/beta_{algo}.pickle', 'rb') as handle:
    kt_mal_beta_lfn = pickle.load(handle)

  

  plt.rcParams['text.usetex'] = True
  
  fig = plt.figure(figsize=(8, 4))
  # fig.suptitle('SFN datasets with Gaussian additive noise', fontsize=12)
  # plt.title(dimensionality + ' ' + noise_type)

  fig.add_subplot(1, 2, 1) # .title.set_text(dimensionality + ' ' + noise_type)
  # plt.title(dimensionality + ' ' + noise_type)
  plt.plot(alphas_add, kt_add_alpha, color='#1f77b4')
  plt.plot(alphas_mal, kt_mal_alpha, color='#1f77b4', linestyle=':')
  plt.plot(alphas_add_lfn, kt_add_alpha_lfn, color='#ff7f0e')
  plt.plot(alphas_mal_lfn, kt_mal_alpha_lfn, color='#ff7f0e', linestyle=':')

  plt.legend([
    'Additive noise - SFN',
    'Mallows noise - SFN',
    'Additive noise - LFN',
    'Mallows noise - LFN'
    ],
    framealpha=0.6,
    loc=3,
    fontsize=10
  )
  plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.yticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.xlabel(f"$\{'alpha'}$")
  plt.ylabel("Mean KT coefficient")
  plt.grid(visible=True, which='major', color='0.8', linestyle='-')
  plt.grid(visible=True, which='minor', color='0.9', linestyle='--')
  plt.minorticks_on()

  fig.add_subplot(1, 2, 2) #.title.set_text(dimensionality + ' ' + noise_type)
  # plt.title(dimensionality + ' ' + noise_type)

  plt.plot(betas_add, kt_add_beta, color='#1f77b4')
  plt.plot(betas_mal, kt_mal_beta, color='#1f77b4', linestyle=':')
  plt.plot(betas_add_lfn, kt_add_beta_lfn, color='#ff7f0e')
  plt.plot(betas_mal_lfn, kt_mal_beta_lfn, color='#ff7f0e', linestyle=':')
  plt.legend([
    'Additive noise - SFN',
    'Mallows noise - SFN',
    'Additive noise - LFN',
    'Mallows noise - LFN'
    ],
    #title=dimensionality,
    framealpha=0.6,
    loc=3,
    fontsize=10
  )
  plt.xticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.yticks([0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.xlabel(f"$\{'beta'}$")
  #plt.ylabel("Mean KT coefficient")
  plt.grid(visible=True, which='major', color='0.8', linestyle='-')
  plt.grid(visible=True, which='minor', color='0.9', linestyle='--')
  plt.minorticks_on()

  plt.savefig(f'plots/{algo}.pdf')
  plt.show()

# %%
plot3(algo='labelwise_rf')
plot3(algo='pairwise_rf')
plot3(algo='labelwise_dt')
plot3(algo='pairwise_dt')
plot3(algo='labelwise_lr')
plot3(algo='pairwise_hh')
