# %%
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
from label_ranking import *
from massart import *


d = 10  # data dimension
k = 5  # labels
epsilon = 0.2  # upper bound for classification error
delta = 0.3  # 1 - delta is the confidence

# Feature vectors distribution
D = multivariate_normal(mean=np.zeros(d), cov=np.identity(d))

# Linear Sorting Function
W_opt = np.random.rand(k, d)

# Train data
X_train = D.rvs(size=200000)

R_train = ground_truth_permutations(X_train, W_opt)
P_train = np.argsort(R_train, axis=1)

# Test data
X_test = D.rvs(size=10000)

R_test = ground_truth_permutations(X_test, W_opt)
P_test = np.argsort(R_test, axis=1)

# %%
eta_max = 0.1
R_train_noisy = np.array([addNoise(y, eta_max) for y in R_train])
P_train_noisy = np.argsort(R_train_noisy, axis=1)

V = pairwiseHalfspaces(
  X=X_train,
  P=P_train_noisy,
  epsilon=epsilon,
  delta=delta,
  eta_max=eta_max,
  constants=(1e-9, 100, 10, 10)
)

# Test accuracy of output halfspace
print(np.mean([ranking_accuracy(X_test[i], P_test[i], V) for i in range(len(X_test))]))
# Out:
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3436
# eta = 0.1
# beta = 17.05977984837351
# sigma = 0.03286442746786685
# N = 50887
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3436
# eta = 0.1
# beta = 17.05977984837351
# sigma = 0.03286442746786685
# N = 50887
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3436
# eta = 0.1
# beta = 17.05977984837351
# sigma = 0.03286442746786685
# N = 50887
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3436
# eta = 0.1
# beta = 17.05977984837351
# sigma = 0.03286442746786685
# N = 50887
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3436
# eta = 0.1
# beta = 17.05977984837351
# sigma = 0.03286442746786685
# N = 50887
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3436
# eta = 0.1
# beta = 17.05977984837351
# sigma = 0.03286442746786685
# N = 50887
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3436
# eta = 0.1
# beta = 17.05977984837351
# sigma = 0.03286442746786685
# N = 50887
#
# d = 10
# epsilon = 0.05
# ...

# %%
eta_max = 0.2
R_train_noisy = np.array([addNoise(y, eta_max) for y in R_train])
P_train_noisy = np.argsort(R_train_noisy, axis=1)

V = pairwiseHalfspaces(
  X=X_train,
  P=P_train_noisy,
  epsilon=epsilon,
  delta=delta,
  eta_max=eta_max,
  constants=(5*1e-11, 100, 10, 10)
)

# Test accuracy of output halfspace
print(np.mean([ranking_accuracy(X_test[i], P_test[i], V) for i in range(len(X_test))]))
# Out:
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3051
# eta = 0.2
# beta = 18.10418155311895
# sigma = 0.028461429068003783
# N = 89146
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3051
# eta = 0.2
# beta = 18.10418155311895
# sigma = 0.028461429068003783
# N = 89146
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3051
# eta = 0.2
# beta = 18.10418155311895
# sigma = 0.028461429068003783
# N = 89146
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3051
# eta = 0.2
# beta = 18.10418155311895
# sigma = 0.028461429068003783
# N = 89146
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3051
# eta = 0.2
# beta = 18.10418155311895
# sigma = 0.028461429068003783
# N = 89146
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3051
# eta = 0.2
# beta = 18.10418155311895
# sigma = 0.028461429068003783
# N = 89146
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3051
# eta = 0.2
# beta = 18.10418155311895
# sigma = 0.028461429068003783
# N = 89146
#
# d = 10
# epsilon = 0.05
# ...

# %%
eta_max = 0.3
R_train_noisy = np.array([addNoise(y, eta_max) for y in R_train])
P_train_noisy = np.argsort(R_train_noisy, axis=1)

V = pairwiseHalfspaces(
  X=X_train,
  P=P_train_noisy,
  epsilon=epsilon,
  delta=delta,
  eta_max=eta_max,
  constants=(1e-12, 100, 10, 1)
)

# Test accuracy of output halfspace
print(np.mean([ranking_accuracy(X_test[i], P_test[i], V) for i in range(len(X_test))]))
# Out:
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3518
# eta = 0.3
# beta = 16.859786954334187
# sigma = 0.023238659522342088
# N = 20414
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3518
# eta = 0.3
# beta = 16.859786954334187
# sigma = 0.023238659522342088
# N = 20414
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3518
# eta = 0.3
# beta = 16.859786954334187
# sigma = 0.023238659522342088
# N = 20414
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3518
# eta = 0.3
# beta = 16.859786954334187
# sigma = 0.023238659522342088
# N = 20414
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3518
# eta = 0.3
# beta = 16.859786954334187
# sigma = 0.023238659522342088
# N = 20414
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3518
# eta = 0.3
# beta = 16.859786954334187
# sigma = 0.023238659522342088
# N = 20414
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3518
# eta = 0.3
# beta = 16.859786954334187
# sigma = 0.023238659522342088
# N = 20414
#
# d = 10
# epsilon = 0.05
# ...

# %%
eta_max = 0.4
R_train_noisy = np.array([addNoise(y, eta_max) for y in R_train])
P_train_noisy = np.argsort(R_train_noisy, axis=1)

V = pairwiseHalfspaces(
  X=X_train,
  P=P_train_noisy,
  epsilon=epsilon,
  delta=delta,
  eta_max=eta_max,
  constants=(1e-15, 100, 10, 1)
)

# Test accuracy of output halfspace
print(np.mean([ranking_accuracy(X_test[i], P_test[i], V) for i in range(len(X_test))]))
# Out:
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3603
# eta = 0.4
# beta = 16.659726559488114
# sigma = 0.016432213733933422
# N = 81895
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3603
# eta = 0.4
# beta = 16.659726559488114
# sigma = 0.016432213733933422
# N = 81895
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3603
# eta = 0.4
# beta = 16.659726559488114
# sigma = 0.016432213733933422
# N = 81895
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3603
# eta = 0.4
# beta = 16.659726559488114
# sigma = 0.016432213733933422
# N = 81895
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3603
# eta = 0.4
# beta = 16.659726559488114
# sigma = 0.016432213733933422
# N = 81895
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3603
# eta = 0.4
# beta = 16.659726559488114
# sigma = 0.016432213733933422
# N = 81895
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 3603
# eta = 0.4
# beta = 16.659726559488114
# sigma = 0.016432213733933422
# N = 81895
#
# d = 10
# epsilon = 0.05
# ...

# %%
eta_max = 0.48
R_train_noisy = np.array([addNoise(y, eta_max) for y in R_train])
P_train_noisy = np.argsort(R_train_noisy, axis=1)

V = pairwiseHalfspaces(
  X=X_train,
  P=P_train_noisy,
  epsilon=epsilon,
  delta=delta,
  eta_max=eta_max,
  constants=(1e-23, 100, 10, 0.1)
)

# Test accuracy of output halfspace
print(np.mean([ranking_accuracy(X_test[i], P_test[i], V) for i in range(len(X_test))]))
# Out:
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 351
# eta = 0.48
# beta = 53.37605126836238
# sigma = 0.007348709385976159
# N = 146519
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 351
# eta = 0.48
# beta = 53.37605126836238
# sigma = 0.007348709385976159
# N = 146519
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 351
# eta = 0.48
# beta = 53.37605126836238
# sigma = 0.007348709385976159
# N = 146519
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 351
# eta = 0.48
# beta = 53.37605126836238
# sigma = 0.007348709385976159
# N = 146519
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 351
# eta = 0.48
# beta = 53.37605126836238
# sigma = 0.007348709385976159
# N = 146519
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 351
# eta = 0.48
# beta = 53.37605126836238
# sigma = 0.007348709385976159
# N = 146519
#
# d = 10
# epsilon = 0.05
# delta = 0.0012
# T = 351
# eta = 0.48
# beta = 53.37605126836238
# sigma = 0.007348709385976159
# N = 146519
#
# d = 10
# epsilon = 0.05
# ...
